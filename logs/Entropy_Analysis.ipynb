# %% [markdown]
# # Entropy Analysis

# %%
from utils.logits_utils import *
from utils.entropy_utils import *

import pandas as pd

choices_df, games_df = load_all_game_data()

# %%
all_models = [
    'Gemma_2B',
    'Gemma_2B_Instruct',
    'Qwen_0.5B',
    'Qwen_1.5B',
    'Qwen_3B',
    'Qwen_3B_Instruct',
    'Qwen_3B_quantized',
    'Qwen_3B_Instruct_quantized',
    'Qwen_7B',
    'Qwen_7B_Instruct',
    'Qwen_7B_quantized',
    'Qwen_7B_Instruct_quantized'
]

# %%
entroy_plots = {}

for model in all_models:
    entroy_plots[model] = plot_entropy_by_round(
        choices_df,
        games_df,
        model,
        4
    )
